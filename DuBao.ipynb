# %%
# from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt, expm1
import numpy as np
from sklearn.metrics import mean_squared_error
from numpy import genfromtxt, savetxt

def saveImage(y_true, y_pred, path,title):
	print(y_true)
	x = range(1,len(y_true)+1)
	fig = plt.figure()
	plt.plot(x, y_true, label='Thuc Do'.format(i=1))
	plt.plot(x, y_pred,linestyle="--", linewidth =2, label='Website'.format(i=2),color="red")
	plt.legend(loc='best')
	plt.subplots_adjust(top=0.83)
	arrTitle = title.split(",")
	plt.title(title+"\n")
	fig.savefig(path, dpi=fig.dpi*2)

def dochinhxac(y_true,y_pred):
	result = [];
	for i in range(0,len(y_true)):
		if y_true[i] > 0:
			lech = abs(y_pred[i] - y_true[i])/y_true[i]
			result.insert(0,1-lech)
	return np.mean(result)

def caculateIndex(arrPredict,test_y,dirPath = "",strDetail=""):
	key = 0;
	Sum_ME = 0;
	Sum_MEA = 0;	
	Sum_RMSE = 0;		
	for i in arrPredict:
		# caculate 
		Sum_ME += (arrPredict[key]-test_y[key])
		# (MAE)
		Sum_MEA += abs(arrPredict[key]-test_y[key])
		#(RMSE):
		Sum_RMSE += (arrPredict[key]-test_y[key])**2
		key = key+1
	AVG_ME=Sum_ME/(key+1)
	AVG_MEA=Sum_MEA/(key+1)
	AVG_RMSE= sqrt(Sum_RMSE/(key+1))
	PercentChinhXac = dochinhxac(test_y,arrPredict)
	f= open(dirPath,"w+")
	f.write("%s, ME: %s,MEA: %s,RMSE: %s, Do Chinh Xac: %s\n" % (strDetail, AVG_ME,AVG_MEA,AVG_RMSE,PercentChinhXac))
	f.close()
	
# Max Temperature
arrDb = ['LuongMua','DoAm','NhietDoCao','MatTroi','NhietDoThap','Gio']
arrAl = ['5,1,0','1,0,0','5,1,0','2,1,0','4,1,0','2,0,1']
keyDb = 2
nameDb = arrDb[keyDb]
print(nameDb)
month = 3
print(month)
for district in range(1,32):
	series = read_csv('tempature_2019/'+str(month)+'.csv', header=-1, parse_dates=[0], index_col=0, squeeze=True)
	X = series.values
	#size = len(X) - 31 # Day last
	train = X[2:size,district]
	history = train
	print(history)
	#savetxt("Result/"+nameDb+str(month)+"_TrueValue.txt", test, delimiter=',')
	predictions = list()
	history = [x for x in train]
	for t in range(31):
		p,d,q = '5,1,0'.split(",")
		print(history,np.array('5,1,0'.split(",")))
		model = ARIMA(history, order=(int(p),int(d),int(q)))
		model_fit = model.fit(disp=0)
		output = model_fit.forecast()
		yhat = output[0]
		predictions.append(yhat)
		history.append(obs)
		print('predicted=%f, expected=%f' % (yhat, obs))
	#saveImage(test, predictions, "Result/"+nameDb+"_"+str(month)+".png",nameDb+" Month:"+str(month))
	#caculateIndex(predictions,test,"Result/"+nameDb+".txt",nameDb+".txt")
	pass

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt, expm1
import numpy as np
from sklearn.metrics import mean_squared_error
from numpy import genfromtxt, savetxt

def saveImage(y_true, y_pred, path,title):
	print(y_true)
	x = range(1,len(y_true)+1)
	fig = plt.figure()
	plt.plot(x, y_true, label='Thuc Do'.format(i=1))
	plt.plot(x, y_pred,linestyle="--", linewidth =2, label='Website'.format(i=2),color="red")
	plt.legend(loc='best')
	plt.subplots_adjust(top=0.83)
	arrTitle = title.split(",")
	plt.title(title+"\n")
	fig.savefig(path, dpi=fig.dpi*2)

def dochinhxac(y_true,y_pred):
	result = [];
	for i in range(0,len(y_true)):
		if y_true[i] > 0:
			lech = abs(y_pred[i] - y_true[i])/y_true[i]
			result.insert(0,1-lech)
	return np.mean(result)

def caculateIndex(arrPredict,test_y,dirPath = "",strDetail=""):
	key = 0;
	Sum_ME = 0;
	Sum_MEA = 0;		
	Sum_RMSE = 0;		
	for i in arrPredict:
		# caculate 
		Sum_ME += (arrPredict[key]-test_y[key])
		# (MAE)
		Sum_MEA += abs(arrPredict[key]-test_y[key])
		#(RMSE):
		Sum_RMSE += (arrPredict[key]-test_y[key])**2
		key = key+1
	AVG_ME=Sum_ME/(key+1)
	AVG_MEA=Sum_MEA/(key+1)
	AVG_RMSE= sqrt(Sum_RMSE/(key+1))
	PercentChinhXac = dochinhxac(test_y,arrPredict)
	with open(dirPath, "ab") as myfile:
		myfile.write("%s, ME: %s,MEA: %s,RMSE: %s, Do Chinh Xac: %s\n" % (strDetail, AVG_ME,AVG_MEA,AVG_RMSE,PercentChinhXac))
# Date
# Precipitation
# Relative Humidity
# Max Temperature
# Solar
# Min Temperature
# Wind
arrDb = ['LuongMua','DoAm','NhietDoCao','MatTroi','NhietDoThap','Gio']
arrAl = ['5,1,0','1,0,0','5,1,0','2,1,0','4,1,0','2,0,1']
nameDb = arrDb[keyDb];

for district in range(1,25):
    for month in range(3,4):
        print(month)
        series = read_csv('tempature_2019/'+str(month)+'.csv', header=-1, parse_dates=[0], index_col=0, squeeze=True)
        X = series.values
        train = X[0:len(X),district]
        dataset = train
        #savetxt("Result/"+nameDb+str(month)+"_TrueValue.txt", test, delimiter=',')
        predictions = list()
        dataset = [x for x in train]
        numYear = 4 
        for t in range(31):
            history = [];
            for year in range(0,numYear):
                #print(t+(year*31))
                history.append(dataset[t+(year*31)])
            model = ARIMA(history, order=(1,1,0))
            model_fit = model.fit(disp=0)
            output = model_fit.forecast()
            yhat = output[0]
            predictions.append(yhat[0])
            history.append(yhat[0])
            print('predicted=%f' % (yhat[0]))

        #error = mean_squared_error(test, predictions)
        #print('Test MSE: %.3f' % error)
        savetxt("Result/"+str(district)+"_"+str(month)+".txt", predictions, delimiter=',')
        #saveImage(test, predictions, "Result/"+nameDb+"_"+str(month)+".png",nameDb+" Month:"+str(month))
        #caculateIndex(predictions,test,"Result/"+nameDb+".txt",nameDb+".txt")
        pass
# Out:
# NhietDoCao
# 3
# 124
# predicted=28.625890]
# predicted=26.462202]
# predicted=29.870758]
# predicted=30.445018]
# predicted=26.568232]
# predicted=28.384913]
# predicted=28.830482]
# predicted=28.668340]
# predicted=28.005896]
# predicted=28.596392]
# predicted=26.082910]
# predicted=27.430020]
# predicted=29.990526]
# predicted=30.539689]
# predicted=28.111461]
# predicted=29.633706]
# predicted=28.242432]
# predicted=27.806923]
# predicted=29.575061]
# predicted=28.484349]
# predicted=28.839040]
# predicted=30.010286]
# predicted=29.837931]
# predicted=29.767321]
# predicted=26.857968]
# predicted=28.296055]
# predicted=28.648176]
# predicted=30.893980]
# predicted=27.245933]
# predicted=27.962398]
# predicted=27.895413]

# %%
print(history)
# Out:
# [31.75, 25.89, 28.46, 29.57]

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt, expm1
import numpy as np
from sklearn.metrics import mean_squared_error
from numpy import genfromtxt, savetxt

def saveImage(y_true, y_pred, path,title):
	print(y_true)
	x = range(1,len(y_true)+1)
	fig = plt.figure()
	plt.plot(x, y_true, label='Thuc Do'.format(i=1))
	plt.plot(x, y_pred,linestyle="--", linewidth =2, label='Website'.format(i=2),color="red")
	plt.legend(loc='best')
	plt.subplots_adjust(top=0.83)
	arrTitle = title.split(",")
	plt.title(title+"\n")
	fig.savefig(path, dpi=fig.dpi*2)

def dochinhxac(y_true,y_pred):
	result = [];
	for i in range(0,len(y_true)):
		if y_true[i] > 0:
			lech = abs(y_pred[i] - y_true[i])/y_true[i]
			result.insert(0,1-lech)
	return np.mean(result)

def caculateIndex(arrPredict,test_y,dirPath = "",strDetail=""):
	key = 0;
	Sum_ME = 0;
	Sum_MEA = 0;		
	Sum_RMSE = 0;		
	for i in arrPredict:
		# caculate 
		Sum_ME += (arrPredict[key]-test_y[key])
		# (MAE)
		Sum_MEA += abs(arrPredict[key]-test_y[key])
		#(RMSE):
		Sum_RMSE += (arrPredict[key]-test_y[key])**2
		key = key+1
	AVG_ME=Sum_ME/(key+1)
	AVG_MEA=Sum_MEA/(key+1)
	AVG_RMSE= sqrt(Sum_RMSE/(key+1))
	PercentChinhXac = dochinhxac(test_y,arrPredict)
	with open(dirPath, "ab") as myfile:
		myfile.write("%s, ME: %s,MEA: %s,RMSE: %s, Do Chinh Xac: %s\n" % (strDetail, AVG_ME,AVG_MEA,AVG_RMSE,PercentChinhXac))
# Date
# Precipitation
# Relative Humidity
# Max Temperature
# Solar
# Min Temperature
# Wind
arrDb = ['LuongMua','DoAm','NhietDoCao','MatTroi','NhietDoThap','Gio']
arrAl = ['5,1,0','1,0,0','5,1,0','2,1,0','4,1,0','2,0,1']
nameDb = arrDb[keyDb];

for district in range(0,24):
    for month in range(4,5):
        print(month, district)
        series = read_csv('tempature_2019/'+str(month)+'.csv', header=-1, parse_dates=[0], index_col=0, squeeze=True)
        X = series.values
        train = X[0:len(X),district]
        dataset = train
        #savetxt("Result/"+nameDb+str(month)+"_TrueValue.txt", test, delimiter=',')
        predictions = list()
        dataset = [x for x in train]
        numYear = 4 
        for t in range(31):
            history = [];
            for year in range(0,numYear):
                #print(t+(year*31))
                history.append(dataset[t+(year*31)])
            model = ARIMA(history, order=(1,1,0))
            model_fit = model.fit(disp=0)
            output = model_fit.forecast()
            yhat = output[0]
            predictions.append(yhat[0])
            history.append(yhat[0])
            print('predicted=%f' % (yhat[0]))

        #error = mean_squared_error(test, predictions)
        #print('Test MSE: %.3f' % error)
        savetxt("Result/"+str(district)+"_"+str(month)+".txt", predictions, delimiter=',')
        #saveImage(test, predictions, "Result/"+nameDb+"_"+str(month)+".png",nameDb+" Month:"+str(month))
        #caculateIndex(predictions,test,"Result/"+nameDb+".txt",nameDb+".txt")
        pass
# Out:
# 4 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-a558c31eea4d> in <module>
#      76                 #print(t+(year*31))
#      77                 history.append(dataset[t+(year*31)])
# ---> 78             model = ARIMA(history, order=(1,1,0))
#      79             model_fit = model.fit(disp=0)
#      80             output = model_fit.forecast()
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     994         else:
#     995             mod = super(ARIMA, cls).__new__(cls)
# --> 996             mod.__init__(endog, order, exog, dates, freq, missing)
#     997             return mod
#     998
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1016         self.k_diff = d
#    1017         self._first_unintegrate = unintegrate_levels(self.endog[:d], d)
# -> 1018         self.endog = np.diff(self.endog, n=d)
#    1019         #NOTE: will check in ARMA but check again since differenced now
#    1020         _check_estimable(len(self.endog), p+q)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/function_base.py in diff(a, n, axis)
#    1172     op = not_equal if a.dtype == np.bool_ else subtract
#    1173     for _ in range(n):
# -> 1174         a = op(a[slice1], a[slice2])
#    1175
#    1176     return a
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U5') dtype('<U5') dtype('<U5')

# %%
train = X[0:len(X),0]

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt, expm1
import numpy as np
from sklearn.metrics import mean_squared_error
from numpy import genfromtxt, savetxt

def saveImage(y_true, y_pred, path,title):
	print(y_true)
	x = range(1,len(y_true)+1)
	fig = plt.figure()
	plt.plot(x, y_true, label='Thuc Do'.format(i=1))
	plt.plot(x, y_pred,linestyle="--", linewidth =2, label='Website'.format(i=2),color="red")
	plt.legend(loc='best')
	plt.subplots_adjust(top=0.83)
	arrTitle = title.split(",")
	plt.title(title+"\n")
	fig.savefig(path, dpi=fig.dpi*2)

def dochinhxac(y_true,y_pred):
	result = [];
	for i in range(0,len(y_true)):
		if y_true[i] > 0:
			lech = abs(y_pred[i] - y_true[i])/y_true[i]
			result.insert(0,1-lech)
	return np.mean(result)

def caculateIndex(arrPredict,test_y,dirPath = "",strDetail=""):
	key = 0;
	Sum_ME = 0;
	Sum_MEA = 0;		
	Sum_RMSE = 0;		
	for i in arrPredict:
		# caculate 
		Sum_ME += (arrPredict[key]-test_y[key])
		# (MAE)
		Sum_MEA += abs(arrPredict[key]-test_y[key])
		#(RMSE):
		Sum_RMSE += (arrPredict[key]-test_y[key])**2
		key = key+1
	AVG_ME=Sum_ME/(key+1)
	AVG_MEA=Sum_MEA/(key+1)
	AVG_RMSE= sqrt(Sum_RMSE/(key+1))
	PercentChinhXac = dochinhxac(test_y,arrPredict)
	with open(dirPath, "ab") as myfile:
		myfile.write("%s, ME: %s,MEA: %s,RMSE: %s, Do Chinh Xac: %s\n" % (strDetail, AVG_ME,AVG_MEA,AVG_RMSE,PercentChinhXac))
# Date
# Precipitation
# Relative Humidity
# Max Temperature
# Solar
# Min Temperature
# Wind
arrDb = ['LuongMua','DoAm','NhietDoCao','MatTroi','NhietDoThap','Gio']
arrAl = ['5,1,0','1,0,0','5,1,0','2,1,0','4,1,0','2,0,1']
nameDb = arrDb[keyDb];

for district in range(0,24):
    for month in range(4,5):
        print(month, district)
        series = read_csv('tempature_2019/'+str(month)+'.csv', header=-1, parse_dates=[0], index_col=0, squeeze=True)
        X = series.values
        train = X[0:len(X),district]
        dataset = train
        #savetxt("Result/"+nameDb+str(month)+"_TrueValue.txt", test, delimiter=',')
        predictions = list()
        dataset = [x for x in train]
        numYear = 4 
        for t in range(30):
            history = [];
            for year in range(0,numYear):
                history.append(dataset[t+(year*30)])
            model = ARIMA(history, order=(1,1,0))
            model_fit = model.fit(disp=0)
            output = model_fit.forecast()
            yhat = output[0]
            predictions.append(yh
# predicted=32.202564
# predicted=30.700161
# predicted=30.677904
# predicted=30.720544
# predicted=34.025240
# predicted=31.035861
# predicted=32.597932
# predicted=33.891077
# predicted=30.985643
# predicted=31.646988
# predicted=30.044496
# predicted=29.469461
# 4 21
# predicted=33.759739
# predicted=31.459163
# predicted=31.573115
# predicted=30.420440
# predicted=30.804448
# predicted=31.484526
# predicted=31.644692
# predicted=33.341919
# predicted=30.420676
# predicted=31.924079
# predicted=32.596317
# predicted=29.397464
# predicted=32.682600
# predicted=31.668820
# predicted=29.590887
# predicted=32.674188
# predicted=29.754658
# predicted=30.386023
# predicted=30.456100
# predicted=30.943746
# predicted=34.229758
# predicted=33.024619
# predicted=30.539299
# predicted=31.716362
# predicted=31.555099
# predicted=29.945105
# predicted=31.558729
# predicted=30.906053
# predicted=32.898602
# predicted=32.154170
# 4 22
# predicted=32.545829
# predicted=33.635593
# predicted=31.972487
# predicted=33.034707
# predicted=33.647714
# predicted=32.450818
# predicted=31.375011
# predicted=33.278628
# predicted=32.598345
# predicted=33.165516
# predicted=32.110917
# predicted=32.440309
# predicted=32.475926
# predicted=31.885616
# predicted=33.039221
# predicted=33.067553
# predicted=32.707969
# predicted=35.062890
# predicted=34.019873
# predicted=31.776637
# predicted=32.833560
# predicted=33.295365
# predicted=32.315806
# predicted=31.507414
# predicted=31.714568
# predicted=32.315871
# predicted=32.751962
# predicted=32.330268
# predicted=33.500984
# predicted=31.942213
# 4 23
# predicted=29.451384
# predicted=33.204516
# predicted=32.429801
# predicted=32.533140
# predicted=31.650805
# predicted=34.218139
# predicted=32.179598
# predicted=31.762907
# predicted=31.549913
# predicted=30.970859
# predicted=30.022367
# predicted=29.831391
# predicted=29.316473
# predicted=29.577569
# predicted=32.834268
# predicted=33.635529
# predicted=32.849729
# predicted=33.057779
# predicted=32.130566
# predicted=30.244658
# predicted=33.255174
# predicted=31.387098
# predicted=31.553532
# predicted=33.361243
# predicted=30.865122
# predicted=32.804964
# predicted=32.145365
# predicted=32.756041
# predicted=31.770138
# predicted=32.382247

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt, expm1
import numpy as np
from sklearn.metrics import mean_squared_error
from numpy import genfromtxt, savetxt

def saveImage(y_true, y_pred, path,title):
	print(y_true)
	x = range(1,len(y_true)+1)
	fig = plt.figure()
	plt.plot(x, y_true, label='Thuc Do'.format(i=1))
	plt.plot(x, y_pred,linestyle="--", linewidth =2, label='Website'.format(i=2),color="red")
	plt.legend(loc='best')
	plt.subplots_adjust(top=0.83)
	arrTitle = title.split(",")
	plt.title(title+"\n")
	fig.savefig(path, dpi=fig.dpi*2)

def dochinhxac(y_true,y_pred):
	result = [];
	for i in range(0,len(y_true)):
		if y_true[i] > 0:
			lech = abs(y_pred[i] - y_true[i])/y_true[i]
			result.insert(0,1-lech)
	return np.mean(result)

def caculateIndex(arrPredict,test_y,dirPath = "",strDetail=""):
	key = 0;
	Sum_ME = 0;
	Sum_MEA = 0;		
	Sum_RMSE = 0;		
	for i in arrPredict:
		# caculate 
		Sum_ME += (arrPredict[key]-test_y[key])
		# (MAE)
		Sum_MEA += abs(arrPredict[key]-test_y[key])
		#(RMSE):
		Sum_RMSE += (arrPredict[key]-test_y[key])**2
		key = key+1
	AVG_ME=Sum_ME/(key+1)
	AVG_MEA=Sum_MEA/(key+1)
	AVG_RMSE= sqrt(Sum_RMSE/(key+1))
	PercentChinhXac = dochinhxac(test_y,arrPredict)
	with open(dirPath, "ab") as myfile:
		myfile.write("%s, ME: %s,MEA: %s,RMSE: %s, Do Chinh Xac: %s\n" % (strDetail, AVG_ME,AVG_MEA,AVG_RMSE,PercentChinhXac))
# Date
# Precipitation
# Relative Humidity
# Max Temperature
# Solar
# Min Temperature
# Wind
# arrDb = ['LuongMua','DoAm','NhietDoCao','MatTroi','NhietDoThap','Gio']
# arrAl = ['5,1,0','1,0,0','5,1,0','2,1,0','4,1,0','2,0,1']
# nameDb = arrDb[keyDb];

for district in range(0,24):
    for month in range(4,5): 
        print(month, district)
        # read database month from csv 
        series = read_csv('tempature_2019/'+str(month)+'.csv', header=-1, parse_dates=[0], index_col=0, squeeze=True)
        X = series.values
        train = X[0:len(X),district]
        dataset = train
        #savetxt("Result/"+nameDb+str(month)+"_TrueValue.txt", test, delimiter=',')
        predictions = list()
        dataset = [x for x in train]
        numYear = 4 
        for t in range(30):
            history = [];
            for year in range(0,numYear):
                history.append(dataset[t+(year*30)])
            model = ARIMA(history, order=(1,1,0))
            model_fit = model.fit(disp=0)
            output = model_fit.forecast()
            yhat = output[0]
            predictions.append(yhat[0])
            history.append(yhat[0])
            print('predicted=%f' % (yhat[0]))

        #error = mean_squared_error(test, predictions)
        #print('Test MSE: %.3f' % error)
        savetxt("Result/"+str(district)+"_"+str(month)+".txt", predictions, delimiter=',')
        #saveImage(test, predictions, "Result/"+nameDb+"_"+str(month)+".png",nameDb+" Month:"+str(month))
        #caculateIndex(predictions,test,"Result/"+nameDb+".txt",nameDb+".txt")
        pass
# Out:
# 4 0
# predicted=31.573964
# predicted=30.428045
# predicted=32.872117
# predicted=33.668901
# predicted=32.778756
# predicted=31.546933
# predicted=31.262394
# predicted=29.441736
# predicted=31.888902
# predicted=29.396658
# predicted=29.661392
# predicted=32.395452
# predicted=30.526286
# predicted=30.743732
# predicted=32.199400
# predicted=29.544235
# predicted=30.295568
# predicted=31.158195
# predicted=29.291170
# predicted=33.466860
# predicted=31.992469
# predicted=32.061813
# predicted=32.324142
# predicted=30.847434
# predicted=31.574564
# predicted=32.009782
# predicted=30.616799
# predicted=30.487430
# predicted=31.347323
# predicted=31.699044
# 4 1
# predicted=30.469310
# predicted=26.173549
# predicted=27.145992
# predicted=28.728663
# predicted=27.012445
# predicted=29.182270
# predicted=30.028852
# predicted=25.478402
# predicted=26.696096
# predicted=27.254041
# predicted=28.171805
# predicted=26.838343
# predicted=27.465636
# predicted=28.185838
# predicted=28.846242
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1e161bd02df3> in <module>
#      77                 history.append(dataset[t+(year*30)])
#      78             model = ARIMA(history, order=(1,1,0))
# ---> 79             model_fit = model.fit(disp=0)
#      80             output = model_fit.forecast()
#      81             yhat = output[0]
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1155                                            method, transparams, solver,
#    1156                                            maxiter, full_output, disp,
# -> 1157                                            callback, start_ar_lags, **kwargs)
#    1158         normalized_cov_params = None  # TODO: fix this?
#    1159         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     957                                        maxiter=maxiter,
#     958                                        full_output=full_output, disp=disp,
# --> 959                                        callback=callback, **kwargs)
#     960         params = mlefit.params
#     961
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     464                                                        callback=callback,
#     465                                                        retall=retall,
# --> 466                                                        full_output=full_output)
#     467
#     468         # NOTE: this is for fit_regularized and should be generalized
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     189                             disp=disp, maxiter=maxiter, callback=callback,
#     190                             retall=retall, full_output=full_output,
# --> 191                             hess=hessian)
#     192
#     193         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     408                                      callback=callback, args=fargs,
#     409                                      bounds=bounds, disp=disp,
# --> 410                                      **extra_kwargs)
#     411
#     412     if full_output:
#
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     438
#     439         def f(params, *args):
# --> 440             return -self.loglike(params, *args) / nobs
#     441
#     442         if method == 'newton':
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     778         method = self.method
#     779         if method in ['mle', 'css-mle']:
# --> 780             return self.loglike_kalman(params, set_sigma2)
#     781         elif method == 'css':
#     782             return self.loglike_css(params, set_sigma2)
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     788         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     789         """
# --> 790         return KalmanFilter.loglike(params, self, set_sigma2)
#     791
#     792     def loglike_css(self, params, set_sigma2=True):
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     647             loglike, sigma2 =  kalman_loglike.kalman_loglike_double(y, k,
#     648                                     k_ar, k_ma, k_lags, int(nobs), Z_mat,
# --> 649                                     R_mat, T_mat)
#     650         elif issubdtype(paramsdtype, np.complex128):
#     651             loglike, sigma2 =  kalman_loglike.kalman_loglike_complex(y, k,
#
# kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# /opt/conda/lib/python3.7/site-packages/numpy/linalg/linalg.py in pinv(a, rcond)
#    1873
#    1874     # discard small singular values
# -> 1875     cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#    1876     large = s > cutoff
#    1877     s = divide(1, s, where=large, out=s)
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial)
#    2225
#    2226
# -> 2227 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue):
#    2228     """
#    2229     Return the maximum of an array or maximum along an axis.
#
# KeyboardInterrupt:
